# %% [markdown]
# ANOVA Test for Accuracy

# %%
import numpy as np
from scipy import stats



proposed_model = [
    100, 100, 100, 94.12, 94.12, 100, 82.35, 100, 100, 88.24,
    100, 88.24, 94.12, 100, 88.24, 94.12, 94.12, 94.12, 94.12, 100,
    94.12, 100, 88.24,94.12,94.12, 100, 100, 100, 88.24]

inceptionv3_lstm_cov = [
    94.12, 88.24, 94.12, 94.12, 94.12, 100, 82.35, 100, 100, 94.12,
    100, 88.24, 94.12, 100, 94.12, 88.24, 100, 94.12, 76.47, 94.12,
    88.24, 100, 88.24, 94.12, 94.12, 100, 100, 100, 94.12]

mlcnn_cov = [
    94.12, 94.12, 94.12, 88.24, 94.12, 100, 82.35, 100, 100, 88.24,
    94.12, 82.35, 94.12, 100, 88.24, 82.35, 100, 94.12, 88.24, 94.12,
    88.24, 100, 88.24, 94.12, 94.12, 100, 100, 100, 94.12]

mobilenetv2 = [94.12, 82.35, 82.35, 94.12, 88.24, 82.35, 76.47, 94.12, 94.12, 88.24,
               82.35, 64.71, 94.12, 94.12, 88.24, 64.71, 82.35, 58.82, 58.82, 70.59,
               76.47, 94.12, 58.82, 94.12, 94.12, 94.12, 100, 76.47, 76.47]


inceptionv3 = [82.35, 82.35, 82.35, 100, 70.59, 82.35, 76.47, 88.24, 88.24, 88.24,
               82.35, 64.71, 94.12, 82.35, 88.24,  76.47, 88.24, 82.35, 58.82, 82.35,
               58.82, 94.12, 76.47, 88.24, 94.12, 94.12, 94.12, 88.24, 70.59]

vgg19 = [88.24, 70.59, 82.35, 88.24, 70.59, 76.47, 76.47, 94.12, 82.35,88.24,
         88.24,  64.71, 94.12, 88.24, 88.24, 58.82, 82.35, 76.47,35.29, 82.35,
         64.71, 94.12, 52.94, 88.24, 94.12, 88.24, 88.24, 76.47, 76.47]


densenet201 = [94.12, 76.49, 82.35, 88.24, 94.12, 82.35, 76.47, 88.24, 88.24, 88.24,
               88.24, 64.71, 88.24, 64.71, 88.24, 64.71, 76.47, 76.47, 58.82, 76.47,
               76.47, 94.12, 64.71, 88.24, 94.12, 94.12, 94.12, 82.35, 70.59]


xception = [94.12, 76.47, 88.24, 88.24, 70.59, 82.35, 76.47, 94.12, 94.12, 88.24,
            76.47,64.71, 100, 82.35, 88.24, 64.71, 88.24,76.47, 58.82, 82.35,
            76.47, 94.12, 64.71, 88.24, 94.12, 94.12, 94.12, 88.24, 82.35]

cnn_blstm = [100, 100, 94.12, 88.24, 94.12, 100, 82.35, 100, 94.12, 88.24,
             100, 82.35, 94.12, 100, 88.24, 100, 100,  94.12, 94.12, 100,
             94.12, 100, 88.24, 94.12, 94.12, 100, 100, 100, 88.24]



# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(
    proposed_model,
    inceptionv3_lstm_cov,
    mlcnn_cov,
    inceptionv3,
    mobilenetv2,
    densenet201,
    vgg19,
    xception,
    cnn_blstm
)

print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 14.582403842861018
# P-value: 1.7716376026828588e-17

# %% [markdown]
# # ANOVA Test for Hamming Loss

# %%
import numpy as np
from scipy import stats

# Define the lists
proposed_model = [
    100, 100, 100, 94.12, 94.12, 100, 82.35, 100, 100, 88.24,
    100, 88.24, 94.12, 100, 88.24, 94.12, 94.12, 94.12, 94.12, 100,
    94.12, 100, 88.24, 94.12, 94.12, 100, 100, 100, 88.24
]

inceptionv3_lstm_cov = [
    94.12, 88.24, 94.12, 94.12, 94.12, 100, 82.35, 100, 100, 94.12,
    100, 88.24, 94.12, 100, 94.12, 88.24, 100, 94.12, 76.47, 94.12,
    88.24, 100, 88.24, 94.12, 94.12, 100, 100, 100, 94.12
]

mlcnn_cov = [
    94.12, 94.12, 94.12, 88.24, 94.12, 100, 82.35, 100, 100, 88.24,
    94.12, 82.35, 94.12, 100, 88.24, 82.35, 100, 94.12, 88.24, 94.12,
    88.24, 100, 88.24, 94.12, 94.12, 100, 100, 100, 94.12
]

mobilenetv2 = [
    94.12, 82.35, 82.35, 94.12, 88.24, 82.35, 76.47, 94.12, 94.12, 88.24,
    82.35, 64.71, 94.12, 94.12, 88.24, 64.71, 82.35, 58.82, 58.82, 70.59,
    76.47, 94.12, 58.82, 94.12, 94.12, 94.12, 100, 76.47, 76.47
]

inceptionv3 = [
    82.35, 82.35, 82.35, 100, 70.59, 82.35, 76.47, 88.24, 88.24, 88.24,
    82.35, 64.71, 94.12, 82.35, 88.24, 76.47, 88.24, 82.35, 58.82, 82.35,
    58.82, 94.12, 76.47, 88.24, 94.12, 94.12, 94.12, 88.24, 70.59
]

vgg19 = [
    88.24, 70.59, 82.35, 88.24, 70.59, 76.47, 76.47, 94.12, 82.35, 88.24,
    88.24, 64.71, 94.12, 88.24, 88.24, 58.82, 82.35, 76.47, 35.29, 82.35,
    64.71, 94.12, 52.94, 88.24, 94.12, 88.24, 88.24, 76.47, 76.47
]

densenet201 = [
    94.12, 76.49, 82.35, 88.24, 94.12, 82.35, 76.47, 88.24, 88.24, 88.24,
    88.24, 64.71, 88.24, 64.71, 88.24, 64.71, 76.47, 76.47, 58.82, 76.47,
    76.47, 94.12, 64.71, 88.24, 94.12, 94.12, 94.12, 82.35, 70.59
]

xception = [
    94.12, 76.47, 88.24, 88.24, 70.59, 82.35, 76.47, 94.12, 94.12, 88.24,
    76.47, 64.71, 100, 82.35, 88.24, 64.71, 88.24, 76.47, 58.82, 82.35,
    76.47, 94.12, 64.71, 88.24, 94.12, 94.12, 94.12, 88.24, 82.35
]

cnn_blstm = [
    100, 100, 94.12, 88.24, 94.12, 100, 82.35, 100, 94.12, 88.24,
    100, 82.35, 94.12, 100, 88.24, 100, 100, 94.12, 94.12, 100,
    94.12, 100, 88.24, 94.12, 94.12, 100, 100, 100, 88.24
]

# Subtract 100 from each value in the lists
proposed_model = [x - 100 for x in proposed_model]
inceptionv3_lstm_cov = [x - 100 for x in inceptionv3_lstm_cov]
mlcnn_cov = [x - 100 for x in mlcnn_cov]
mobilenetv2 = [x - 100 for x in mobilenetv2]
inceptionv3 = [x - 100 for x in inceptionv3]
vgg19 = [x - 100 for x in vgg19]
densenet201 = [x - 100 for x in densenet201]
xception = [x - 100 for x in xception]
cnn_blstm = [x - 100 for x in cnn_blstm]

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(
    proposed_model,
    inceptionv3_lstm_cov,
    mlcnn_cov,
    inceptionv3,
    mobilenetv2,
    densenet201,
    vgg19,
    xception,
    cnn_blstm
)

print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 14.582403842861021
# P-value: 1.7716376026828588e-17

# %% [markdown]
# #ANOVA Test for Precision

# %%
import numpy as np
from scipy import stats



proposed_model = [100, 75, 100, 0, 100, 100, 100, 87.5, 91.67, 100,
                  100, 100, 90.91, 100, 0, 0, 100, 100, 83.33, 0,
                  100, 100, 66.67, 100, 100, 100, 100, 100, 100]

inceptionv3_lstm_cov = [100, 80, 100, 0, 100, 100, 100, 100, 84.62, 77.78,
                        100, 100, 83.33, 100, 100, 0, 100, 100, 83.33, 100,
                        100, 100, 66.67, 100, 100, 100, 80, 93.33 ,0]

mlcnn_cov = [100, 80, 100, 0, 100, 100, 100, 100, 84.62, 88.89,
             100, 100, 76.92, 100, 0, 0, 100, 93.75, 80, 0,
             100, 100, 66.67, 100, 100, 0, 100, 93.33, 0]

mobilenetv2 = [0, 0, 100, 0, 0, 100, 0, 60, 73.33, 60,
               25, 33.33, 62.50, 0, 0, 0, 100, 87.50, 50, 0,
               0, 100, 0, 80, 0, 100, 100, 82.35, 0]

inceptionv3 = [0, 0, 0, 0, 0, 0, 0, 100, 66.67, 58.33,
	            0, 100, 71.43, 100, 0, 0, 0, 87.50, 50, 0,
              0, 0, 0, 50, 0, 100, 100, 82.35, 100]

vgg19 = [0, 0, 0, 0, 0, 0, 0, 0, 64, 40,
         0, 0, 58.82, 0, 0, 0, 0, 88.24, 0, 0,
         0, 0, 0, 0, 0, 0, 0, 82.35, 0]


densenet201 = [0, 0, 0, 0, 0, 50, 0, 100, 73.33, 60,
               0, 50, 64.29, 33.33, 0, 33.33, 0, 88.24, 50, 0,
               0, 0, 0, 100, 0, 0, 100, 82.35, 0]


xception = [0, 66.67, 0, 0, 0, 0, 0, 100, 73.33, 62.5,
            0, 0, 62.5, 100, 0, 100, 0, 86.67, 50, 0,
            0, 100, 50, 50, 0, 0, 100, 87.5, 0]

cnn_blstm = [100, 75, 100, 0, 100, 100, 100, 87.50, 91.667, 100,
             100, 100, 100, 100, 0, 0, 100, 100, 80, 0,
             100, 100, 66.667, 100, 100, 0, 100, 93.33, 100]



# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(
    proposed_model,
    inceptionv3_lstm_cov,
    mlcnn_cov,
    inceptionv3,
    mobilenetv2,
    densenet201,
    vgg19,
    xception,
    cnn_blstm
)

print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 15.000655254724181
# P-value: 6.003460147574573e-18

# %% [markdown]
# #ANOVA Test for Recall

# %%
import numpy as np
from scipy import stats



proposed_model = [100, 75, 100, 0 ,100, 50, 100, 87.50, 100, 88.89,
                  100, 75, 100, 66.67, 0, 0, 100, 100, 83.33, 0,
                  100, 100, 50, 80, 100, 50, 100, 100, 100]

inceptionv3_lstm_cov = [100, 100, 100, 0, 100, 50, 100, 75, 100, 77.78,
                        66.67, 75, 100, 100, 50, 0, 100, 100, 83.33, 50,
                        100, 100, 50 , 80, 100, 50, 80, 100, 0]

mlcnn_cov = [100, 100, 100, 0, 100, 50, 100, 75, 100, 88.89,
             66.67, 75, 100, 100, 0, 0, 100, 100, 66.67, 0,
             100, 100, 50, 80, 100, 0, 80, 100, 0]

mobilenetv2 = [0, 0, 100, 0, 0, 50, 0, 37.5, 100, 66.67,
               33.33, 75, 100, 0, 0, 0, 50, 93., 50, 0,
               0, 50, 0, 80, 0, 50, 40, 100, 0]


inceptionv3 = [0, 0, 0, 0, 0, 0, 0, 50, 72.73, 77.78,
	             0, 25, 100, 33.33, 0, 0, 0, 93.33, 33.33, 0,
               0, 0, 0, 20, 0, 100, 40, 100, 0]

vgg19 = [0, 0, 0, 0, 0, 0, 0, 0, 100, 44.44,
         0, 0, 100, 0, 0, 0, 0, 100, 0, 0,
         0, 0, 0, 0, 0, 0, 0, 100, 0]

densenet201 = [0, 0, 0, 0, 0, 50, 0, 25, 100, 66.67,
               0, 25, 90, 33.33, 0, 100, 0, 100, 16.67, 0,
               0, 0, 0, 80, 0, 0, 20, 100, 0]


xception = [0, 50, 0, 0, 0, 0, 0, 25, 100, 55.56,
            0, 0, 100, 33.33, 0, 100, 0, 86.67, 16.67, 0,
            0, 50, 25, 20, 0, 0, 20, 100, 0]

cnn_blstm = [100, 75, 100, 0, 100, 50, 100, 87.5, 100, 88.889,
             100, 75, 100, 100, 0, 0, 100, 100, 66.667, 0,
             100, 50, 50, 80, 100, 0, 100, 100, 100]


# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(
    proposed_model,
    inceptionv3_lstm_cov,
    mlcnn_cov,
    inceptionv3,
    mobilenetv2,
    densenet201,
    vgg19,
    xception,
    cnn_blstm
)

print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 13.896061643506194
# P-value: 1.0650281491151764e-16

# %% [markdown]
# # ANOVA Test for F1 Score

# %%
import numpy as np
from scipy import stats



proposed_model = [100, 75, 100, 0, 100, 66.67, 100, 87.5, 95.65, 94.12,
                  100, 85.71, 95.24, 80, 0, 0, 100, 100, 83.33, 0,
                  100, 100, 57.14, 88.89, 100, 66.67, 100, 100, 100]


inceptionv3_lstm_cov = [100, 88.89, 100, 0, 100, 66.67, 100, 85.71, 91.67, 77.78,
                        80, 85.71, 90.91, 100, 66.67, 0,  100, 100, 83.33, 66.67,
                        100, 100, 57.14, 88.89, 100, 66.67, 80 ,96.55, 0 ]


mlcnn_cov = [ 100, 88.89, 100, 0, 100, 66.67, 100, 85.71, 91.67, 88.89,
             80, 85.71, 86.96, 100, 0, 0, 100, 96.77, 72.73, 0,
             100,100, 57.14, 88.89, 100, 0, 88.89, 96.55, 0]


mobilenetv2 = [0, 0, 100, 0, 0, 66.67, 0, 46.15, 84.62, 63.16,
               28.57, 46.15, 76.92, 0, 0, 0, 66.67, 90.32, 50, 0,
               0, 66.67, 0, 80, 0, 66.67, 57.14, 90.32, 0]



inceptionv3 = [0, 0, 0, 0, 0, 0, 0, 66.67, 69.57, 66.67,
	            0, 40, 83.33, 50, 0, 0, 0, 90.32, 40, 0,
              0, 0, 0, 28.57, 0, 100, 57.14, 90.32, 0]

vgg19 = [0, 0, 0, 0, 0, 0, 0, 0,  78.57, 42.11,
         0, 0, 74.07, 0, 0, 0, 0, 93.75, 0, 0,
         0, 0, 0, 0, 0, 0, 0, 90.32, 0]



densenet201 = [0, 0, 0, 0, 0, 50, 0, 40, 84.62, 63,
               0, 33.33, 75, 33.33, 0, 50, 0, 93.75, 25, 0,
               0, 0, 0, 88.89, 0, 0, 33.33, 90.32, 0]



xception = [0, 57.14, 0, 0, 0, 0, 0, 40, 84.62, 58.82,
            0, 0, 76.92, 50, 0, 100, 0, 86.67, 25, 0,
            0, 66.67, 33.33, 28.57, 0, 0, 33.33, 93.33, 0]

cnn_blstm = [100, 75, 100, 0, 100, 66.667, 100, 87.5, 95.652, 94.118,
             100, 85,814, 100, 100, 0, 0, 100, 100, 72.727, 0,
             100, 66.667, 57.143, 88.889, 100, 0, 100, 96.552, 100]




# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(proposed_model, inceptionv3_lstm_cov, mlcnn_cov, inceptionv3, mobilenetv2, densenet201, vgg19, xception, cnn_blstm)

print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 8.524746184233544
# P-value: 2.8571075024137655e-10

# %% [markdown]
# #ANOVA Test for ROC

# %%
import numpy as np
from scipy import stats



proposed_model = [100, 84, 100, 50, 100, 75, 100, 83, 92, 94,
       100, 88, 100, 83, 50, 50, 100, 100, 79, 75,
       100, 100, 71, 80, 100, 50, 100, 96, 100]

inceptionv3_lstm_cov = [100, 96, 100, 50, 100, 75, 100, 88, 83, 76,
       80, 88, 86, 100, 75, 50, 100, 100, 87, 75,
       100, 100, 71, 90, 100, 75, 86, 83, 50]

mlcnn_cov = [100, 96, 100, 50, 100, 75, 100, 88, 83, 88,
       83, 88, 79, 100, 50, 50, 100, 75, 79, 50,
       100, 100, 71, 90, 100, 50, 90, 83, 50]

mobilenetv2 = [50, 55, 50, 94, 50, 75, 50, 57, 67, 58,
      67, 75, 52, 67, 50, 50, 50, 50, 53, 75,
      50, 50, 50, 70, 46, 100, 46, 43, 50]


inceptionv3 = [50, 46, 50, 50, 50, 50, 50, 51, 75, 76,
       46, 62, 86, 83, 50, 50, 50, 50, 62, 50,
       47, 50, 50, 66, 50, 50, 60, 50, 47]

vgg19 = [50, 50, 50, 50, 47, 75, 50, 50, 50, 46,
       46, 50, 50, 50, 75, 50, 47, 50, 50, 50,
       50, 50, 50, 50, 50, 50, 50, 46, 50]


densenet201 = [50, 46, 50, 50, 50, 75, 47, 58, 49, 50,
       50, 46, 50, 46, 75, 50, 50, 50, 49, 50,
       50, 50, 50, 66, 39, 97, 66, 43, 50]


xception = [50, 59, 94, 100, 50, 50, 100, 62, 67, 77,
      67, 75, 57, 67, 50, 50, 50, 47, 62, 50,
      50, 75, 46, 70, 50, 50, 60, 63,50]

cnn_blstm = [100, 84, 100, 50, 100, 75, 100, 94, 92, 94,
       100, 88, 93, 100, 50, 50, 100, 100, 79, 50,
       100, 75, 71, 90, 100, 75, 100, 100, 100]



# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(
    proposed_model,
    inceptionv3_lstm_cov,
    mlcnn_cov,
    inceptionv3,
    mobilenetv2,
    densenet201,
    vgg19,
    xception,
    cnn_blstm
)

print(f"F-statistic: {f_statistic}")
print(f"P-value: {p_value}")
# Out:
# F-statistic: 32.05398488357735
# P-value: 1.7903064434916962e-34
